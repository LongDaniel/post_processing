# %%
#import neccesary library
import sys
import h5py
import numpy as np
import tecplot_io as tec
import os
import matplotlib as mpl
import matplotlib.pyplot as plt 
import matplotlib.ticker as tck

# %%
#change working directory
path = 'd:\post\Project\Fixed_Turbine'
path0 = 'd:\post\Project\Fixed_Turbine'
path1 = 'd:\post\Project\Pitch_Turbine'
path2 = 'd:\post\Project\SWAY_Turbine'
os.chdir(path)
print("current working directory is: {0}".format(os.getcwd()))
# Out:
# current working directory is: d:\post\Project\Fixed_Turbine

# %%
#open nessesary file
fname = 'restart_hos.h5'
f = h5py.File(fname, "r")
eta = f["eta_hos"]
nx = eta.shape[0]
x = np.linspace(0, 2240, nx)
#print(eta[1,:])

# %%
plt.plot(x, eta[0,:], label='eta_hos')
plt.show()

# %%
print(eta[0,48])
print(eta[0,144])
print(eta[0,240])
print(eta[0,336])
print(np.max(eta[0,:]))
# Out:
# 1.1530526277658033
# 1.153052627765841
# 1.1530526277657718
# 1.1530526277658495
# 1.5165177408858754

# %%
theta = np.arcsin(eta[0,48]/np.max(eta[0,:]))
theta1 = np.arcsin(1)
print(theta)
print(theta1)
# Out:
# 0.8638196922607861
# 1.5707963267948966
