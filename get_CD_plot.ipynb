# %%
#change working directory to the directory of this script
import os
import sys
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path = 'd:\post\SWAY_9'
#path = 'd:\post'
os.chdir(path)
#print working directory
print(os.getcwd())
# Out:
# d:\post

# %%
print(os.getcwd())
#open file nacelle002.inp
f = open('CD00','r')
#skip the 2 first lines
f.readline()
f.readline()
number_of_line= f.readline()
print(number_of_line)
data=np.zeros((int(number_of_line),2))
#declare an array with 35 rows and 2 columns
#data=np.zeros((35,2))
for i in range (0,int(number_of_line)):
#for i in range (35):
    line = f.readline()
    line = line.split()
    data[i,0]= line[0]
    data[i,1]= line[1]
f.close() 

data = pd.DataFrame(data)
x = data[0]
y = data[1]
print(data)

 


plt.plot(x, y)
plt.show()
# Out:
# d:\post
# 104
#
#           0        1
# 0   -180.43  0.00318
# 1   -175.52  0.02549
# 2   -170.36  0.10809
# 3   -165.37  0.19029
# 4   -160.18  0.28511
# ..      ...      ...
# 99   160.18  0.28511
# 100  165.37  0.19029
# 101  170.36  0.10809
# 102  175.52  0.02549
# 103  180.43  0.00318
#
# [104 rows x 2 columns]
